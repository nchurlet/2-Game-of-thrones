# %% [markdown]
# # Game of Thrones
#
# Are you a fan of the Game of Thrones series? Let's test it. Let's use the API : [https://anapioficeandfire.com/](https://anapioficeandfire.com/) to find out more about the series

# %% [markdown]
# 0. Import the following libraries:
#
#       * ```requests```
#       * ```pandas```
#       * ```json```

# %%
import requests as req
import pandas as pd
import json

# %% [markdown]
# 1. Go to the URL indicated in the description above. Using requests, get data on a character in the series. It doesn't matter who the character is

# %%
req.get('https://anapioficeandfire.com/api/characters/2').content
# Out:
# b'{"url":"https://anapioficeandfire.com/api/characters/2","name":"Walder","gender":"Male","culture":"","born":"","died":"","titles":[""],"aliases":["Hodor"],"father":"","mother":"","spouse":"","allegiances":["https://anapioficeandfire.com/api/houses/362"],"books":["https://anapioficeandfire.com/api/books/1","https://anapioficeandfire.com/api/books/2","https://anapioficeandfire.com/api/books/3","https://anapioficeandfire.com/api/books/5","https://anapioficeandfire.com/api/books/8"],"povBooks":[],"tvSeries":["Season 1","Season 2","Season 3","Season 4","Season 6"],"playedBy":["Kristian Nairn"]}'

# %%
# Rendu

# %% [markdown]
# 2. Extract these data in JSON format.

# %%
# Out:
# {'aliases': ['Hodor'],
#  'allegiances': ['https://www.anapioficeandfire.com/api/houses/362'],
#  'books': ['https://www.anapioficeandfire.com/api/books/1',
#   'https://www.anapioficeandfire.com/api/books/2',
#   'https://www.anapioficeandfire.com/api/books/3',
#   'https://www.anapioficeandfire.com/api/books/5',
#   'https://www.anapioficeandfire.com/api/books/8'],
#  'born': '',
#  'culture': '',
#  'died': '',
#  'father': '',
#  'gender': 'Male',
#  'mother': '',
#  'name': 'Walder',
#  'playedBy': ['Kristian Nairn'],
#  'povBooks': [],
#  'spouse': '',
#  'titles': [''],
#  'tvSeries': ['Season 1', 'Season 2', 'Season 3', 'Season 4', 'Season 6'],
#  'url': 'https://www.anapioficeandfire.com/api/characters/2'}

# %% [markdown]
# 3. Now extract the JSON keys you have obtained and create a DataFrame that will have the JSON keys you extracted as a column.
#
#         * Hint, we can use:
#
#   ```
#   r.json().keys()
#   ```

# %%
# Out:
# Empty DataFrame
# Columns: [url, name, gender, culture, born, died, titles, aliases, father, mother, spouse, allegiances, books, povBooks, tvSeries, playedBy]
# Index: []

# %% [markdown]
# 4. Create a loop to extract data from the first 150 characters of the series and add them to your DataFrame.

# %%
# Out:
# 2 personnage done
# 3 personnage done
# 4 personnage done
# 5 personnage done
# 6 personnage done
# 7 personnage done
# 8 personnage done
# 9 personnage done
# 10 personnage done
# 11 personnage done
# 12 personnage done
# 13 personnage done
# 14 personnage done
# 15 personnage done
# 16 personnage done
# 17 personnage done
# 18 personnage done
# 19 personnage done
# 20 personnage done
# 21 personnage done
# 22 personnage done
# 23 personnage done
# 24 personnage done
# 25 personnage done
# 26 personnage done
# 27 personnage done
# 28 personnage done
# 29 personnage done
# 30 personnage done
# 31 personnage done
# 32 personnage done
# 33 personnage done
# 34 personnage done
# 35 personnage done
# 36 personnage done
# 37 personnage done
# 38 personnage done
# 39 personnage done
# 40 personnage done
# 41 personnage done
# 42 personnage done
# 43 personnage done
# 44 personnage done
# 45 personnage done
# 46 personnage done
# 47 personnage done
# 48 personnage done
# 49 personnage done
# 50 personnage done
# 51 personnage done
# 52 personnage done
# 53 personnage done
# 54 personnage done
# 55 personnage done
# 56 personnage done
# 57 personnage done
# 58 personnage done
# 59 personnage done
# 60 personnage done
# 61 personnage done
# 62 personnage done
# 63 personnage done
# 64 personnage done
# 65 personnage done
# 66 personnage done
# 67 personnage done
# 68 personnage done
# 69 personnage done
# 70 personnage done
# 71 personnage done
# 72 personnage done
# 73 personnage done
# 74 personnage done
# 75 personnage done
# 76 personnage done
# 77 personnage done
# 78 personnage done
# 79 personnage done
# 80 personnage done
# 81 personnage done
# 82 personnage done
# 83 personnage done
# 84 personnage done
# 85 personnage done
# 86 personnage done
# 87 personnage done
# 88 personnage done
# 89 personnage done
# 90 personnage done
# 91 personnage done
# 92 personnage done
# 93 personnage done
# 94 personnage done
# 95 personnage done
# 96 personnage done
# 97 personnage done
# 98 personnage done
# 99 personnage done
# 100 personnage done
# 101 personnage done
# 102 personnage done
# 103 personnage done
# 104 personnage done
# 105 personnage done
# 106 personnage done
# 107 personnage done
# 108 personnage done
# 109 personnage done
# 110 personnage done
# 111 personnage done
# 112 personnage done
# 113 personnage done
# 114 personnage done
# 115 personnage done
# 116 personnage done
# 117 personnage done
# 118 personnage done
# 119 personnage done
# 120 personnage done
# 121 personnage done
# 122 personnage done
# 123 personnage done
# 124 personnage done
# 125 personnage done
# 126 personnage done
# 127 personnage done
# 128 personnage done
# 129 personnage done
# 130 personnage done
# 131 personnage done
# 132 personnage done
# 133 personnage done
# 134 personnage done
# 135 personnage done
# 136 personnage done
# 137 personnage done
# 138 personnage done
# 139 personnage done
# 140 personnage done
# 141 personnage done
# 142 personnage done
# 143 personnage done
# 144 personnage done
# 145 personnage done
# 146 personnage done
# 147 personnage done
# 148 personnage done
# 149 personnage done
# 150 personnage done
# 151 personnage done
# 152 personnage done
# 153 personnage done
# 154 personnage done
# 155 personnage done
# 156 personnage done
# 157 personnage done
# 158 personnage done
# 159 personnage done
# 160 personnage done
# 161 personnage done
# 162 personnage done
# 163 personnage done
# 164 personnage done
# 165 personnage done
# 166 personnage done
# 167 personnage done
# 168 personnage done
# 169 personnage done
# 170 personnage done
# 171 personnage done
# 172 personnage done
# 173 personnage done
# 174 personnage done
# 175 personnage done
# 176 personnage done
# 177 personnage done
# 178 personnage done
# 179 personnage done
# 180 personnage done
# 181 personnage done
# 182 personnage done
# 183 personnage done
# 184 personnage done
# 185 personnage done
# 186 personnage done
# 187 personnage done
# 188 personnage done
# 189 personnage done
# 190 personnage done
# 191 personnage done
# 192 personnage done
# 193 personnage done
# 194 personnage done
# 195 personnage done
# 196 personnage done
# 197 personnage done
# 198 personnage done
# 199 personnage done
# 200 personnage done
# 201 personnage done
# 202 personnage done
# 203 personnage done
# 204 personnage done
# 205 personnage done
# 206 personnage done
# 207 personnage done
# 208 personnage done
# 209 personnage done
# 210 personnage done
# 211 personnage done
# 212 personnage done
# 213 personnage done
# 214 personnage done
# 215 personnage done
# 216 personnage done
# 217 personnage done
# 218 personnage done
# 219 personnage done
# 220 personnage done
# 221 personnage done
# 222 personnage done
# 223 personnage done
# 224 personnage done
# 225 personnage done
# 226 personnage done
# 227 personnage done
# 228 personnage done
# 229 personnage done
# 230 personnage done
# 231 personnage done
# 232 personnage done
# 233 personnage done
# 234 personnage done
# 235 personnage done
# 236 personnage done
# 237 personnage done
# 238 personnage done
# 239 personnage done
# 240 personnage done
# 241 personnage done
# 242 personnage done
# 243 personnage done
# 244 personnage done
# 245 personnage done
# 246 personnage done
# 247 personnage done
# 248 personnage done
# 249 personnage done
# 250 personnage done
# 251 personnage done
# 252 personnage done
# 253 personnage done
# 254 personnage done
# 255 personnage done
# 256 personnage done
# 257 personnage done
# 258 personnage done
# 259 personnage done
# 260 personnage done
# 261 personnage done
# 262 personnage done
# 263 personnage done
# 264 personnage done
# 265 personnage done
# 266 personnage done
# 267 personnage done
# 268 personnage done
# 269 personnage done
# 270 personnage done
# 271 personnage done
# 272 personnage done
# 273 personnage done
# 274 personnage done
# 275 personnage done
# 276 personnage done
# 277 personnage done
# 278 personnage done
# 279 personnage done
# 280 personnage done
# 281 personnage done
# 282 personnage done
# 283 personnage done
# 284 personnage done
# 285 personnage done
# 286 personnage done
# 287 personnage done
# 288 personnage done
# 289 personnage done
# 290 personnage done
# 291 personnage done
# 292 personnage done
# 293 personnage done
# 294 personnage done
# 295 personnage done
# 296 personnage done
# 297 personnage done
# 298 personnage done
# 299 personnage done
# 300 personnage done
# 301 personnage done
# 302 personnage done
# 303 personnage done
# 304 personnage done
# 305 personnage done
# 306 personnage done
# 307 personnage done
# 308 personnage done
# 309 personnage done
# 310 personnage done
# 311 personnage done
# 312 personnage done
# 313 personnage done
# 314 personnage done
# 315 personnage done
# 316 personnage done
# 317 personnage done
# 318 personnage done
# 319 personnage done
# 320 personnage done
# 321 personnage done
# 322 personnage done
# 323 personnage done
# 324 personnage done
# 325 personnage done
# 326 personnage done
# 327 personnage done
# 328 personnage done
# 329 personnage done
# 330 personnage done
# 331 personnage done
# 332 personnage done
# 333 personnage done
# 334 personnage done
# 335 personnage done
# 336 personnage done
# 337 personnage done
# 338 personnage done
# 339 personnage done
# 340 personnage done
# 341 personnage done
# 342 personnage done
# 343 personnage done
# 344 personnage done
# 345 personnage done
# 346 personnage done
# 347 personnage done
# 348 personnage done
# 349 personnage done
# 350 personnage done
# 351 personnage done
# 352 personnage done
# 353 personnage done
# 354 personnage done
# 355 personnage done
# 356 personnage done
# 357 personnage done
# 358 personnage done
# 359 personnage done
# 360 personnage done
# 361 personnage done
# 362 personnage done
# 363 personnage done
# 364 personnage done
# 365 personnage done
# 366 personnage done
# 367 personnage done
# 368 personnage done
# 369 personnage done
# 370 personnage done
# 371 personnage done
# 372 personnage done
# 373 personnage done
# 374 personnage done
# 375 personnage done
# 376 personnage done
# 377 personnage done
# 378 personnage done
# 379 personnage done
# 380 personnage done
# 381 personnage done
# 382 personnage done
# 383 personnage done
# 384 personnage done
# 385 personnage done
# 386 personnage done
# 387 personnage done
# 388 personnage done
# 389 personnage done
# 390 personnage done
# 391 personnage done
# 392 personnage done
# 393 personnage done
# 394 personnage done
# 395 personnage done
# 396 personnage done
# 397 personnage done
# 398 personnage done
# 399 personnage done
# 400 personnage done
# 401 personnage done
# 402 personnage done
# 403 personnage done
# 404 personnage done
# 405 personnage done
# 406 personnage done
# 407 personnage done
# 408 personnage done
# 409 personnage done
# 410 personnage done
# 411 personnage done
# 412 personnage done
# 413 personnage done
# 414 personnage done
# 415 personnage done
# 416 personnage done
# 417 personnage done
# 418 personnage done
# 419 personnage done
# 420 personnage done
# 421 personnage done
# 422 personnage done
# 423 personnage done
# 424 personnage done
# 425 personnage done
# 426 personnage done
# 427 personnage done
# 428 personnage done
# 429 personnage done
# 430 personnage done
# 431 personnage done
# 432 personnage done
# 433 personnage done
# 434 personnage done
# 435 personnage done
# 436 personnage done
# 437 personnage done
# 438 personnage done
# 439 personnage done
# 440 personnage done
# 441 personnage done
# 442 personnage done
# 443 personnage done
# 444 personnage done
# 445 personnage done
# 446 personnage done
# 447 personnage done
# 448 personnage done
# 449 personnage done
# 450 personnage done
# 451 personnage done
# 452 personnage done
# 453 personnage done
# 454 personnage done
# 455 personnage done
# 456 personnage done
# 457 personnage done
# 458 personnage done
# 459 personnage done
# 460 personnage done
# 461 personnage done
# 462 personnage done
# 463 personnage done
# 464 personnage done
# 465 personnage done
# 466 personnage done
# 467 personnage done
# 468 personnage done
# 469 personnage done
# 470 personnage done
# 471 personnage done
# 472 personnage done
# 473 personnage done
# 474 personnage done
# 475 personnage done
# 476 personnage done
# 477 personnage done
# 478 personnage done
# 479 personnage done
# 480 personnage done
# 481 personnage done
# 482 personnage done
# 483 personnage done
# 484 personnage done
# 485 personnage done
# 486 personnage done
# 487 personnage done
# 488 personnage done
# 489 personnage done
# 490 personnage done
# 491 personnage done
# 492 personnage done
# 493 personnage done
# 494 personnage done
# 495 personnage done
# 496 personnage done
# 497 personnage done
# 498 personnage done
# 499 personnage done
# 500 personnage done
# 501 personnage done

# %%
# Out:
#                                               url    name  gender   culture  \
# 0  https://anapioficeandfire.com/api/characters/2  Walder    Male
# 1  https://anapioficeandfire.com/api/characters/3            Male
# 2  https://anapioficeandfire.com/api/characters/4          Female  Braavosi
# 3  https://anapioficeandfire.com/api/characters/5            Male
# 4  https://anapioficeandfire.com/api/characters/6          Female  Braavosi
#
#   born died titles              aliases father mother spouse  \
# 0               []              [Hodor]
# 1               []            [Lamprey]
# 2               []  [The Merling Queen]
# 3               []     [Old Crackbones]
# 4               []        [The Poetess]
#
#                                       allegiances  \
# 0  [https://anapioficeandfire.com/api/houses/362]
# 1   [https://anapioficeandfire.com/api/houses/15]
# 2                                              []
# 3                                              []
# 4                                              []
#
#                                                books povBooks  \
# 0  [https://anapioficeandfire.com/api/books/1, ht...       []
# 1        [https://anapioficeandfire.com/api/books/3]       []
# 2  [https://anapioficeandfire.com/api/books/5, ht...       []
# 3        [https://anapioficeandfire.com/api/books/5]       []
# 4        [https://anapioficeandfire.com/api/books/5]       []
#
#                                             tvSeries          playedBy
# 0  [Season 1, Season 2, Season 3, Season 4, Seaso...  [Kristian Nairn]
# 1                                                 []                []
# 2                                                 []                []
# 3                                                 []                []
# 4                                                 []                []
